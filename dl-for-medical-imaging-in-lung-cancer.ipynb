# %% [markdown]
# <h1 style="font-family:verdana;"> <center>💻🧠DL for Medical Imaging in Lung Cancer💻🧠</center> </h1>
# <p><center style="color:#159364; font-family:cursive; font-size:20px;">Xoán Fernández, Vicente Piorno, Paula Rodríguez </center></p>

# %% [markdown]
# # ❓**PROBLEM DEFINITION**
# <div style="background-color:#f2f2f2; padding: 20px;">
#   <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# Lung cancer remains a significant global health challenge, with its early detection and type classification being crucial for effective treatment. One detection method involves analyzing CT scan images. These images can then be interpreted by doctors to determine the presence and type of lung cancer. However, this method has limitations; human interpretation may miss subtle patterns indicative of early-stage lung cancer. In contrast, deep learning models offer a promising avenue on this matter. They excel in recognizing intricate patterns, identifying subtle abnormalities not easily observable through other methods. Another advantage is they automatically learn relevant features from data, eliminating the need for manual feature engineeing, which is particulary usefull in medical imaging where definining explicit features can be complex.
#       <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
#       In this study, we use a dataset containing CT scan images of lungs categorized as normal, squamous cell carcinoma, adenocarcinoma and large cell carcinoma. Our objective is to train three different models (VGG16, Inceptionv3 and EfficientNetB0), compare their accuracy and make predictions with the one with hightest accuracy.

# %% [markdown]
# # 🏗️**LIBRARY IMPORT**
# <div style="background-color:#f2f2f2; padding: 20px;">
#   <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# Import necessary libraries for the script. The first libraries are used to interact with the operative system, numerical operations and data visualization.
#       <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# The following ones are specific to machine learning and neural network. TensorFlow is a machine learning framework used to build and deploy machine learning models. Keras is a high-level neural networks API that runs on top of TensorFlow and its used to build, train and deploy neural networks. Keras functionality with TensorFlow is integrated thanks to the "tensorflow.keras" library.
#       <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# In this code, the Keras library modules are imported to serve as tools for specific tasks, such as defining distinct layer types, constructing models, preprocessing image data, implementing callbacks, leveraging pre-trained models for transfer learning, and loading pre-trained models for reuse.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense,Conv2D, Flatten, MaxPool2D, Dropout
from tensorflow.keras import Model 
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.applications.inception_v3 import InceptionV3


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **EDA**

# %%
# File Directory for both the train and test
train_path = "Data/train"
val_path = "Data/valid"
test_path = "Data/test"

# %%
# Define function to count number of images per class using a dictionary
def GetDatasetSize(path):
    num_of_image = {}
    for folder in os.listdir(path):
        # count files in the folder
        num_of_image[folder] = len(os.listdir(os.path.join(path, folder)));
    return num_of_image;

# Get the number of images per class in each set (train, validation and test)
train_set = GetDatasetSize(train_path)
val_set = GetDatasetSize(val_path)
test_set = GetDatasetSize(test_path)
print(train_set,"\n\n",val_set,"\n\n",test_set)
# Out:
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 195, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 115, 'normal': 148, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 155}
#
#  {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 23, 'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 21, 'normal': 13, 'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 15}
#
#  {'adenocarcinoma': 120, 'large.cell.carcinoma': 51, 'normal': 54, 'squamous.cell.carcinoma': 90}

# %%
# Labels for each classs
labels = ['squamous.cell.carcinoma', 'normal', 'adenocarcinoma', 'large.cell.carcinoma']

# Create lists from previous dictionaries storing the count of images per category
train_list = list(train_set.values())
val_list = list(val_set.values())
test_list = list(test_set.values())

# Labels location and bars widht 
x = np.arange(len(labels))  
width = 0.25  

# Create plot and 3 sets of bars (train, val, test)
fig, ax = plt.subplots()
rects1 = ax.bar(x - width, train_list, width, label='Train')
rects2 = ax.bar(x, val_list, width, label='Val')
rects3 = ax.bar(x + width, test_list, width, label='Test')

# Add labels, title, legend, count values...
ax.set_ylabel('Images Count')
ax.set_title('Dataset')
ax.set_xticks(x, labels)
plt.xticks(rotation=15)
ax.legend()
ax.bar_label(rects1)
ax.bar_label(rects2)
ax.bar_label(rects3)

# Optimized layout and displaying plot
fig.tight_layout()
plt.show()

# %% [markdown]
# # ⚙️**DATA PREPROCESSING**
# <div style="background-color:#f2f2f2; padding: 20px;">
#   <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# Data augmentation is performed to artificially increase the diversity of the training dataset by applying various transformations to the existing training samples. As a result, the model's generalization and robustness to different variations in the input data is improved.

# %%
# Image data generator with specified augmentation configurations (mostly geometric transformations)
train_datagen = ImageDataGenerator(rescale = 1.0/255.0,
                                  horizontal_flip = True,
                                  fill_mode = 'nearest',
                                  zoom_range=0.2,
                                  shear_range = 0.2,
                                  width_shift_range=0.2,
                                  height_shift_range=0.2,
                                  rotation_range=0.4)

# Using data generator to create augmented data from image files in train_path directory
train_data = train_datagen.flow_from_directory(train_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')

# Dicctionary with class names to their respective indices in the generated data
train_data.class_indices
# Out:
# Found 613 images belonging to 4 classes.
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
val_datagen = ImageDataGenerator(rescale = 1.0/255.0)
val_data = val_datagen.flow_from_directory(val_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
val_data.class_indices
# Out:
# Found 72 images belonging to 4 classes.
# {'adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib': 0,
#  'large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa': 3}

# %%
test_datagen = ImageDataGenerator(rescale = 1.0/255.0)
test_data = test_datagen.flow_from_directory(test_path,
                                                   batch_size = 5,
                                                   target_size = (350,350),
                                                   class_mode = 'categorical')
test_data.class_indices
# Out:
# Found 315 images belonging to 4 classes.
# {'adenocarcinoma': 0,
#  'large.cell.carcinoma': 1,
#  'normal': 2,
#  'squamous.cell.carcinoma': 3}

# %% [markdown]
# # 👀**SAMPLE VISUALIZATION**
# <div style="background-color:#f2f2f2; padding: 20px;">
#   <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# Ensuring that data preprocessing has been correctly applied and checking whether the labels are correctly assigned.

# %%
# Function to plot sample images with labels
def plot_sample_images(images, labels, class_indices):
    class_labels = list(class_indices.keys())
    fig, axs = plt.subplots(1, len(images), figsize=(15, 5))  
    fig.subplots_adjust(wspace=0.5)  # Adjust the width space between subplots

    for i in range(len(images)):
        axs[i].imshow(images[i])
        axs[i].set_title("Label: {}".format(class_labels[np.argmax(labels[i])]), fontsize=10)  # Adjust fontsize as needed
        axs[i].axis('off')

    plt.show()

# Sample and plotting of 3 images with their respective labels from train_data
sample_images, sample_labels = next(train_data)
plot_sample_images(sample_images[:3], sample_labels[:3], train_data.class_indices)

# %% [markdown]
# # **VGG 16**
# <div>
#   <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# VGG-16, short for Visual Geometry Group 16-layer, is a deep convolutional neural network architecture designed for image classification. It was introduced by the Visual Geometry Group at the University of Oxford in 2014. The VGG architecture gained popularity for its simplicity and effectiveness, and it served as a foundation for many subsequent deep learning models.
#
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# However, it has a relatively large number of parameters, making it computationally expensive. More recent architectures, such as ResNet and EfficientNet, have since surpassed VGG in terms of performance and efficiency.
#
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# Trained on the ImageNet dataset, this model exhibits an accuracy exceeding 80%.
#
#  <p style="font-size:20px">
#     <strong>Batch size</strong>: 32<br>
#     <strong>Epochs</strong>: 32<br>
#     <strong>Input Shape</strong>: (350, 350, 3)<br>
#     <strong>Output layer</strong>: 16
#   </p>
# </div>

# %%
base_model = VGG16(
    weights='imagenet',
    include_top=False, 
    input_shape=(350,350,3)
)

# %% [markdown]
# # Training the model

# %%
# We define the number of classes in the classification problem.
NUM_CLASSES = 4

# First, a sequential model is created, which will be used to build the VGG model.
vgg_model = Sequential()

# Se agrega una capa al modelo. base_model el modelo anteriormente preentrenado.
vgg_model.add(base_model)

# A flattening layer (Flatten) is added. This layer converts the output from the 
# previous layer (which is likely a three-dimensional tensor) into a one-dimensional vector.
vgg_model.add(layers.Flatten())

# A Dropout layer is added with a dropout rate of 25%. Dropout is used to prevent overfitting 
# by randomly disconnecting some neurons during training.
vgg_model.add(layers.Dropout(0.25))

# A dense layer is added with NUM_CLASSES neurons and a sigmoid activation function. 
# This layer produces the final output of the model.
vgg_model.add(layers.Dense(NUM_CLASSES, activation='sigmoid'))

# The first layer of the model (base_model) is frozen, so the weights of this layer 
# will not be updated during training.
vgg_model.layers[0].trainable = False

# The model is compiled with the 'categorical_crossentropy' loss function,
#' adam' optimizer, and the accuracy metric. This prepares the model for training.
vgg_model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
mc = ModelCheckpoint(
    filepath="./ct_vgg_best_model.hdf5",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [ mc];

# %%
# Fitting the Model
vgg = vgg_model.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back 
    )
# Out:
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 2.2072 - accuracy: 0.4474
# Epoch 1: val_accuracy improved from -inf to 0.57143, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 247s 2s/step - loss: 2.2072 - accuracy: 0.4474 - val_loss: 1.0598 - val_accuracy: 0.5714
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 1.7402 - accuracy: 0.5773
# Epoch 2: val_accuracy did not improve from 0.57143
# 122/122 [==============================] - 256s 2s/step - loss: 1.7402 - accuracy: 0.5773 - val_loss: 2.0365 - val_accuracy: 0.4857
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 2.2476 - accuracy: 0.5592
# Epoch 3: val_accuracy improved from 0.57143 to 0.60000, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 249s 2s/step - loss: 2.2476 - accuracy: 0.5592 - val_loss: 2.5744 - val_accuracy: 0.6000
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 1.4768 - accuracy: 0.6513
# Epoch 4: val_accuracy improved from 0.60000 to 0.61429, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 245s 2s/step - loss: 1.4768 - accuracy: 0.6513 - val_loss: 1.5082 - val_accuracy: 0.6143
# Epoch 5/32
# 122/122 [==============================] - ETA: 0s - loss: 1.3569 - accuracy: 0.6694
# Epoch 5: val_accuracy did not improve from 0.61429
# 122/122 [==============================] - 229s 2s/step - loss: 1.3569 - accuracy: 0.6694 - val_loss: 1.9098 - val_accuracy: 0.5429
# Epoch 6/32
# 122/122 [==============================] - ETA: 0s - loss: 1.3899 - accuracy: 0.6908
# Epoch 6: val_accuracy did not improve from 0.61429
# 122/122 [==============================] - 227s 2s/step - loss: 1.3899 - accuracy: 0.6908 - val_loss: 1.8030 - val_accuracy: 0.5714
# Epoch 7/32
# 122/122 [==============================] - ETA: 0s - loss: 1.2866 - accuracy: 0.7023
# Epoch 7: val_accuracy did not improve from 0.61429
# 122/122 [==============================] - 225s 2s/step - loss: 1.2866 - accuracy: 0.7023 - val_loss: 1.9354 - val_accuracy: 0.5286
# Epoch 8/32
# 122/122 [==============================] - ETA: 0s - loss: 1.5431 - accuracy: 0.6875
# Epoch 8: val_accuracy improved from 0.61429 to 0.71429, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 224s 2s/step - loss: 1.5431 - accuracy: 0.6875 - val_loss: 1.2709 - val_accuracy: 0.7143
# Epoch 9/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1918 - accuracy: 0.7418
# Epoch 9: val_accuracy improved from 0.71429 to 0.77143, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 224s 2s/step - loss: 1.1918 - accuracy: 0.7418 - val_loss: 1.3516 - val_accuracy: 0.7714
# Epoch 10/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8966 - accuracy: 0.7336
# Epoch 10: val_accuracy improved from 0.77143 to 0.80000, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 230s 2s/step - loss: 0.8966 - accuracy: 0.7336 - val_loss: 1.0964 - val_accuracy: 0.8000
# Epoch 11/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1435 - accuracy: 0.7484
# Epoch 11: val_accuracy did not improve from 0.80000
# 122/122 [==============================] - 227s 2s/step - loss: 1.1435 - accuracy: 0.7484 - val_loss: 3.2603 - val_accuracy: 0.5143
# Epoch 12/32
# 122/122 [==============================] - ETA: 0s - loss: 1.4157 - accuracy: 0.7253
# Epoch 12: val_accuracy did not improve from 0.80000
# 122/122 [==============================] - 224s 2s/step - loss: 1.4157 - accuracy: 0.7253 - val_loss: 0.8233 - val_accuracy: 0.7857
# Epoch 13/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8829 - accuracy: 0.7944
# Epoch 13: val_accuracy improved from 0.80000 to 0.82857, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 223s 2s/step - loss: 0.8829 - accuracy: 0.7944 - val_loss: 0.9537 - val_accuracy: 0.8286
# Epoch 14/32
# 122/122 [==============================] - ETA: 0s - loss: 1.2134 - accuracy: 0.7747
# Epoch 14: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 225s 2s/step - loss: 1.2134 - accuracy: 0.7747 - val_loss: 1.0998 - val_accuracy: 0.7429
# Epoch 15/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8818 - accuracy: 0.7928
# Epoch 15: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 226s 2s/step - loss: 0.8818 - accuracy: 0.7928 - val_loss: 1.0924 - val_accuracy: 0.7571
# Epoch 16/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8861 - accuracy: 0.8026
# Epoch 16: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 225s 2s/step - loss: 0.8861 - accuracy: 0.8026 - val_loss: 1.5471 - val_accuracy: 0.7714
# Epoch 17/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8686 - accuracy: 0.7961
# Epoch 17: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 224s 2s/step - loss: 0.8686 - accuracy: 0.7961 - val_loss: 2.5536 - val_accuracy: 0.5571
# Epoch 18/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0761 - accuracy: 0.7714
# Epoch 18: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 225s 2s/step - loss: 1.0761 - accuracy: 0.7714 - val_loss: 2.5411 - val_accuracy: 0.6714
# Epoch 19/32
# 122/122 [==============================] - ETA: 0s - loss: 0.9382 - accuracy: 0.8010
# Epoch 19: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 226s 2s/step - loss: 0.9382 - accuracy: 0.8010 - val_loss: 1.9605 - val_accuracy: 0.7286
# Epoch 20/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0629 - accuracy: 0.7697
# Epoch 20: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 224s 2s/step - loss: 1.0629 - accuracy: 0.7697 - val_loss: 2.6319 - val_accuracy: 0.6714
# Epoch 21/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1186 - accuracy: 0.7632
# Epoch 21: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 224s 2s/step - loss: 1.1186 - accuracy: 0.7632 - val_loss: 3.1505 - val_accuracy: 0.6286
# Epoch 22/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0456 - accuracy: 0.8026
# Epoch 22: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 234s 2s/step - loss: 1.0456 - accuracy: 0.8026 - val_loss: 1.4183 - val_accuracy: 0.8143
# Epoch 23/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7365 - accuracy: 0.7878
# Epoch 23: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 226s 2s/step - loss: 0.7365 - accuracy: 0.7878 - val_loss: 1.4050 - val_accuracy: 0.7857
# Epoch 24/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8729 - accuracy: 0.8141
# Epoch 24: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 224s 2s/step - loss: 0.8729 - accuracy: 0.8141 - val_loss: 1.6375 - val_accuracy: 0.7429
# Epoch 25/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8622 - accuracy: 0.8240
# Epoch 25: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 230s 2s/step - loss: 0.8622 - accuracy: 0.8240 - val_loss: 1.5353 - val_accuracy: 0.7286
# Epoch 26/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7642 - accuracy: 0.8273
# Epoch 26: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 237s 2s/step - loss: 0.7642 - accuracy: 0.8273 - val_loss: 1.4574 - val_accuracy: 0.7857
# Epoch 27/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7880 - accuracy: 0.8273
# Epoch 27: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 235s 2s/step - loss: 0.7880 - accuracy: 0.8273 - val_loss: 3.4863 - val_accuracy: 0.6143
# Epoch 28/32
# 122/122 [==============================] - ETA: 0s - loss: 0.9070 - accuracy: 0.8191
# Epoch 28: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 235s 2s/step - loss: 0.9070 - accuracy: 0.8191 - val_loss: 2.7332 - val_accuracy: 0.6714
# Epoch 29/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8763 - accuracy: 0.8076
# Epoch 29: val_accuracy did not improve from 0.82857
# 122/122 [==============================] - 237s 2s/step - loss: 0.8763 - accuracy: 0.8076 - val_loss: 1.1265 - val_accuracy: 0.8286
# Epoch 30/32
# 122/122 [==============================] - ETA: 0s - loss: 0.9936 - accuracy: 0.8207
# Epoch 30: val_accuracy improved from 0.82857 to 0.87143, saving model to .\ct_vgg_best_model.hdf5
# 122/122 [==============================] - 236s 2s/step - loss: 0.9936 - accuracy: 0.8207 - val_loss: 1.1340 - val_accuracy: 0.8714
# Epoch 31/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0342 - accuracy: 0.8158
# Epoch 31: val_accuracy did not improve from 0.87143
# 122/122 [==============================] - 237s 2s/step - loss: 1.0342 - accuracy: 0.8158 - val_loss: 1.4363 - val_accuracy: 0.7286
# Epoch 32/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8031 - accuracy: 0.8553
# Epoch 32: val_accuracy did not improve from 0.87143
# 122/122 [==============================] - 236s 2s/step - loss: 0.8031 - accuracy: 0.8553 - val_loss: 1.2645 - val_accuracy: 0.8000

# %% [markdown]
# # Model Evaluation
# <div>
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">The test dataset will be used to evaluate the performance of the model. The metrics that will be measured are:
#
# <h3>Accuracy(A):</h3>
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">For the purpose of evaluating the performance of the current model and future models, the accuracy metric will be employed. Accuracy measures the proportion of instances correctly classified out of the total instances. It is a general measure of the model's effectiveness across all classes.</p>
#
#   <h4>
#   <center>
#     <span style="font-size: 1.5em">
#       \( A = \frac{TP+TN}{TI} \)
#     </span>
#   </center>
# </h4>
#
# <h3>Loss: </h3>
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">Loss is a measure of how well the model is performing the task for which it was trained. It represents the discrepancy between the model's predictions and the actual labels. A low loss value indicates that the model is making predictions that fit well with the training data.</p>

# %%
# Loading the Best Fit Model 
model = load_model("./ct_vgg_best_model.hdf5")

# Checking the Accuracy of the Model 
accuracy_vgg = model.evaluate_generator(generator= test_data)[1] 
print(f"The accuracy of the model is = {accuracy_vgg*100} %")
loss_vgg = model.evaluate_generator(generator= test_data)[0] 
print(f"The loss of the model is = {loss_vgg}")
# Out:
# The accuracy of the model is = 88.2539689540863 %
# The loss of the model is = 0.5290688872337341

# %% [markdown]
# # **INCEPTIONV3**
# <div style="background-color:#f2f2f2; padding: 20px;">
#   <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# InceptionV3 is a convolutional neural network (CNN) model developed by Google as part of the Inception family of architectures. It is designed for image recognition and classification tasks. The "V3" indicates that it's the third iteration of this architecture. It was designed to improve performance and efficiency compared to its predecessors.
#
#
#   <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# This model has been trained on the ImageNet dataset, showing greater than 78.1%  of accuracy.
#
#  <p style="font-size:20px">
#     <strong>Batch size</strong>: 32<br>
#     <strong>Epochs</strong>: 32<br>
#     <strong>Input Shape</strong>: (350, 350, 3)<br>
#     <strong>Output layer</strong>: 1024
#   </p>
# </div>

# %%
base_model = InceptionV3(input_shape = (350, 350, 3), 
                         include_top = False, 
                         weights = 'imagenet')

# %% [markdown]
# # 🚄Training the model

# %%
# The code then iterates through all layers in the base InceptionV3 model. 
# This means that during training, these layers will not be updated, preserving the pre-trained knowledge.
for layer in base_model.layers:
    layer.trainable = False

# %%
# First, we flatten the information coming out of InceptionV3 (making it simpler).
# We aded another layer for better understanding of the flattened information
x = layers.Flatten()(base_model.output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.2)(x)

# Finally, we add a layer with 4 'neurons' that will help us classify things into different categories.
x = layers.Dense(4, activation='sigmoid')(x)

# We put together the original InceptionV3 and our new custom parts 
model_incep = tf.keras.models.Model(base_model.input, x)

# Compile up the rules and tools for training your neural network. 
# The optimizer determines how the model should update its internal parameters, the loss function quantifies how well the model is doing, and the metrics provide additional measures to track the model's performance.
model_incep.compile(optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001), 
                    loss = 'categorical_crossentropy', 
                    metrics = ['accuracy'])

# %%
# Adding Model check point Callback

mc = ModelCheckpoint(
    filepath="./ct_incep_best_model.hdf5",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [mc];

# %%
# Fitting the Model
incep = model_incep.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = call_back 
    )
# Out:
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 6.7632 - accuracy: 0.4490
# Epoch 1: val_accuracy improved from -inf to 0.54286, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 219s 2s/step - loss: 6.7632 - accuracy: 0.4490 - val_loss: 3.0059 - val_accuracy: 0.5429
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 2.1944 - accuracy: 0.5921
# Epoch 2: val_accuracy improved from 0.54286 to 0.58571, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 213s 2s/step - loss: 2.1944 - accuracy: 0.5921 - val_loss: 1.5662 - val_accuracy: 0.5857
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 1.4505 - accuracy: 0.5872
# Epoch 3: val_accuracy did not improve from 0.58571
# 122/122 [==============================] - 209s 2s/step - loss: 1.4505 - accuracy: 0.5872 - val_loss: 1.2311 - val_accuracy: 0.5571
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 1.1295 - accuracy: 0.6168
# Epoch 4: val_accuracy improved from 0.58571 to 0.62857, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 216s 2s/step - loss: 1.1295 - accuracy: 0.6168 - val_loss: 0.8722 - val_accuracy: 0.6286
# Epoch 5/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8939 - accuracy: 0.6776
# Epoch 5: val_accuracy improved from 0.62857 to 0.72857, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 212s 2s/step - loss: 0.8939 - accuracy: 0.6776 - val_loss: 0.5630 - val_accuracy: 0.7286
# Epoch 6/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8994 - accuracy: 0.7023
# Epoch 6: val_accuracy did not improve from 0.72857
# 122/122 [==============================] - 210s 2s/step - loss: 0.8994 - accuracy: 0.7023 - val_loss: 1.5191 - val_accuracy: 0.5857
# Epoch 7/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8413 - accuracy: 0.6908
# Epoch 7: val_accuracy did not improve from 0.72857
# 122/122 [==============================] - 204s 2s/step - loss: 0.8413 - accuracy: 0.6908 - val_loss: 0.9602 - val_accuracy: 0.6571
# Epoch 8/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8171 - accuracy: 0.7072
# Epoch 8: val_accuracy improved from 0.72857 to 0.78571, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 200s 2s/step - loss: 0.8171 - accuracy: 0.7072 - val_loss: 0.5875 - val_accuracy: 0.7857
# Epoch 9/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7344 - accuracy: 0.7155
# Epoch 9: val_accuracy did not improve from 0.78571
# 122/122 [==============================] - 201s 2s/step - loss: 0.7344 - accuracy: 0.7155 - val_loss: 0.5704 - val_accuracy: 0.7571
# Epoch 10/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7460 - accuracy: 0.7253
# Epoch 10: val_accuracy did not improve from 0.78571
# 122/122 [==============================] - 210s 2s/step - loss: 0.7460 - accuracy: 0.7253 - val_loss: 0.8212 - val_accuracy: 0.6714
# Epoch 11/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6498 - accuracy: 0.7829
# Epoch 11: val_accuracy did not improve from 0.78571
# 122/122 [==============================] - 204s 2s/step - loss: 0.6498 - accuracy: 0.7829 - val_loss: 0.5247 - val_accuracy: 0.7429
# Epoch 12/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6235 - accuracy: 0.7730
# Epoch 12: val_accuracy improved from 0.78571 to 0.81429, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 206s 2s/step - loss: 0.6235 - accuracy: 0.7730 - val_loss: 0.4864 - val_accuracy: 0.8143
# Epoch 13/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.7845
# Epoch 13: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 201s 2s/step - loss: 0.6070 - accuracy: 0.7845 - val_loss: 1.1298 - val_accuracy: 0.6143
# Epoch 14/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6063 - accuracy: 0.7944
# Epoch 14: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 197s 2s/step - loss: 0.6063 - accuracy: 0.7944 - val_loss: 0.6115 - val_accuracy: 0.7571
# Epoch 15/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5461 - accuracy: 0.8026
# Epoch 15: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 203s 2s/step - loss: 0.5461 - accuracy: 0.8026 - val_loss: 1.8003 - val_accuracy: 0.5000
# Epoch 16/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4550 - accuracy: 0.8322
# Epoch 16: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 208s 2s/step - loss: 0.4550 - accuracy: 0.8322 - val_loss: 0.5653 - val_accuracy: 0.7571
# Epoch 17/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5237 - accuracy: 0.8043
# Epoch 17: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 210s 2s/step - loss: 0.5237 - accuracy: 0.8043 - val_loss: 0.7792 - val_accuracy: 0.7000
# Epoch 18/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4525 - accuracy: 0.8405
# Epoch 18: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 211s 2s/step - loss: 0.4525 - accuracy: 0.8405 - val_loss: 0.7367 - val_accuracy: 0.7286
# Epoch 19/32
# 122/122 [==============================] - ETA: 0s - loss: 0.5408 - accuracy: 0.8322
# Epoch 19: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 210s 2s/step - loss: 0.5408 - accuracy: 0.8322 - val_loss: 0.5403 - val_accuracy: 0.7429
# Epoch 20/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.8487
# Epoch 20: val_accuracy did not improve from 0.81429
# 122/122 [==============================] - 210s 2s/step - loss: 0.4604 - accuracy: 0.8487 - val_loss: 0.4761 - val_accuracy: 0.8000
# Epoch 21/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.8487
# Epoch 21: val_accuracy improved from 0.81429 to 0.85714, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 213s 2s/step - loss: 0.4679 - accuracy: 0.8487 - val_loss: 0.5093 - val_accuracy: 0.8571
# Epoch 22/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8470
# Epoch 22: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 212s 2s/step - loss: 0.3874 - accuracy: 0.8470 - val_loss: 0.4501 - val_accuracy: 0.8143
# Epoch 23/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.8355
# Epoch 23: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 211s 2s/step - loss: 0.4987 - accuracy: 0.8355 - val_loss: 0.7086 - val_accuracy: 0.8000
# Epoch 24/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3717 - accuracy: 0.8849
# Epoch 24: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 211s 2s/step - loss: 0.3717 - accuracy: 0.8849 - val_loss: 0.4381 - val_accuracy: 0.8429
# Epoch 25/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3510 - accuracy: 0.8816
# Epoch 25: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 211s 2s/step - loss: 0.3510 - accuracy: 0.8816 - val_loss: 0.5567 - val_accuracy: 0.8286
# Epoch 26/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4029 - accuracy: 0.8602
# Epoch 26: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 212s 2s/step - loss: 0.4029 - accuracy: 0.8602 - val_loss: 0.5093 - val_accuracy: 0.8000
# Epoch 27/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3445 - accuracy: 0.8668
# Epoch 27: val_accuracy did not improve from 0.85714
# 122/122 [==============================] - 213s 2s/step - loss: 0.3445 - accuracy: 0.8668 - val_loss: 0.8368 - val_accuracy: 0.7571
# Epoch 28/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3288 - accuracy: 0.8766
# Epoch 28: val_accuracy improved from 0.85714 to 0.87143, saving model to .\ct_incep_best_model.hdf5
# 122/122 [==============================] - 215s 2s/step - loss: 0.3288 - accuracy: 0.8766 - val_loss: 0.4491 - val_accuracy: 0.8714
# Epoch 29/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8717
# Epoch 29: val_accuracy did not improve from 0.87143
# 122/122 [==============================] - 212s 2s/step - loss: 0.3661 - accuracy: 0.8717 - val_loss: 0.5650 - val_accuracy: 0.8143
# Epoch 30/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8668
# Epoch 30: val_accuracy did not improve from 0.87143
# 122/122 [==============================] - 212s 2s/step - loss: 0.4246 - accuracy: 0.8668 - val_loss: 0.4081 - val_accuracy: 0.8286
# Epoch 31/32
# 122/122 [==============================] - ETA: 0s - loss: 0.2982 - accuracy: 0.9062
# Epoch 31: val_accuracy did not improve from 0.87143
# 122/122 [==============================] - 209s 2s/step - loss: 0.2982 - accuracy: 0.9062 - val_loss: 0.3549 - val_accuracy: 0.8714
# Epoch 32/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3277 - accuracy: 0.8701
# Epoch 32: val_accuracy did not improve from 0.87143
# 122/122 [==============================] - 210s 2s/step - loss: 0.3277 - accuracy: 0.8701 - val_loss: 0.8189 - val_accuracy: 0.7714

# %% [markdown]
# # ✔️Model Evaluation

# %%
# Loading the Best Fit Model 
model = load_model("./ct_incep_best_model.hdf5")

# Checking the Accuracy of the Model 
accuracy_incep = model.evaluate_generator(generator= test_data)[1] 
print(f"The accuracy of the model is = {accuracy_incep*100} %")
loss_incep = model.evaluate_generator(generator= test_data)[0]
print(f"The loss the model is = {loss_incep}%")
# Out:
# The accuracy of the model is = 84.44444537162781 %
# The loss the model is = 0.5026549100875854%

# %% [markdown]
# # **EfficientNetB0**
#
# <div style="background-color:#f2f2f2; padding: 20px;">
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">EfficientNetB0 is a convolutional neural network (CNN) architecture that belongs to the EfficientNet family. Developed by Mingxing Tan and Quoc V. Le, EfficientNetB0 is specifically designed for image recognition and classification tasks. The "B0" signifies that it serves as the baseline or base model within the EfficientNet series.
#
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">It has been also trained on the ImageNet dataset, showing great accuracy for classification tasks.
#
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# However, in comparison with the other models, EfficientNetB0 emphasizes a more balanced approach to model scaling, considering depth, width, and resolution simultaneously. It aims to achieve high performance with fewer parameters and computational resources. It is more efficient in terms of model size and computational cost.
#
#  <div>
#     <p style="font-size:20px">
#     <strong>Batch size</strong>: 32<br>
#     <strong>Epochs</strong>: 32<br>
#     <strong>Input Shape</strong>: (350, 350, 3)<br>
#     <strong>Output layer</strong>: 4
#   </p>
# </div>

# %%
base_model = EfficientNetB0(input_shape = (350, 350, 3), 
                         include_top = False, 
                         weights = 'imagenet')

# %%
mc = ModelCheckpoint(
    filepath="./ct_effnet_best_model.hdf5",
    monitor= 'val_accuracy', 
    verbose= 1,
    save_best_only= True, 
    mode = 'auto'
    );

call_back = [ mc];

tensorboard = TensorBoard(log_dir = 'logs')
reduce_lr = ReduceLROnPlateau(monitor = 'val_accuracy', factor = 0.3, patience = 2, min_delta = 0.001,
                              mode='auto',verbose=1)

#We also add a earlystop for prevent the computer from wasting time if it's not making progress.


early_stopping = EarlyStopping(monitor='val_acc', patience=3, restore_best_weights=True)

# %% [markdown]
# # 🚄Training the model

# %%
#Customize our base model
EffNetmodel = base_model.output
EffNetmodel = tf.keras.layers.GlobalAveragePooling2D()(EffNetmodel)
# to provide overfitting problem
EffNetmodel = tf.keras.layers.Dropout(rate=0.5)(EffNetmodel)

#Finally, we add a layer with 4 'neurons' that will help us classify things into different categories.
EffNetmodel = tf.keras.layers.Dense(4,activation='softmax')(EffNetmodel)

# %%
#We put together the original EfficientNetB0 and our new custom parts 
EffNetmodel = tf.keras.models.Model(inputs=base_model.input, outputs = EffNetmodel)

#Compile up the rules and tools for training your neural network. 
#The optimizer determines how the model should update its internal parameters, the loss function quantifies how well the model is doing, and the metrics provide additional measures to track the model's performance.
EffNetmodel.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
# %time
EffNetB0 = EffNetmodel.fit(
    train_data, 
    steps_per_epoch = train_data.samples//train_data.batch_size, 
    epochs = 32, 
    validation_data = val_data, 
    validation_steps = val_data.samples//val_data.batch_size,
    callbacks = [tensorboard, mc, reduce_lr, early_stopping]
    )
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# Epoch 1/32
# 122/122 [==============================] - ETA: 0s - loss: 1.0829 - accuracy: 0.5181
# Epoch 1: val_accuracy improved from -inf to 0.20000, saving model to .\ct_effnet_best_model.hdf5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 273s 2s/step - loss: 1.0829 - accuracy: 0.5181 - val_loss: 2.0516 - val_accuracy: 0.2000 - lr: 0.0010
# Epoch 2/32
# 122/122 [==============================] - ETA: 0s - loss: 0.8669 - accuracy: 0.6562
# Epoch 2: val_accuracy improved from 0.20000 to 0.25714, saving model to .\ct_effnet_best_model.hdf5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 225s 2s/step - loss: 0.8669 - accuracy: 0.6562 - val_loss: 1.3746 - val_accuracy: 0.2571 - lr: 0.0010
# Epoch 3/32
# 122/122 [==============================] - ETA: 0s - loss: 0.7029 - accuracy: 0.7072
# Epoch 3: val_accuracy improved from 0.25714 to 0.31429, saving model to .\ct_effnet_best_model.hdf5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 224s 2s/step - loss: 0.7029 - accuracy: 0.7072 - val_loss: 8.4656 - val_accuracy: 0.3143 - lr: 0.0010
# Epoch 4/32
# 122/122 [==============================] - ETA: 0s - loss: 0.6846 - accuracy: 0.7401
# Epoch 4: val_accuracy did not improve from 0.31429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 225s 2s/step - loss: 0.6846 - accuracy: 0.7401 - val_loss: 2.1977 - val_accuracy: 0.3143 - lr: 0.0010
# Epoch 5/32
# 122/122 [==============================] - ETA: 0s - loss: 0.4897 - accuracy: 0.8059
# Epoch 5: val_accuracy did not improve from 0.31429
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 227s 2s/step - loss: 0.4897 - accuracy: 0.8059 - val_loss: 1.5690 - val_accuracy: 0.1429 - lr: 0.0010
# Epoch 6/32
# 122/122 [==============================] - ETA: 0s - loss: 0.3714 - accuracy: 0.8734
# Epoch 6: val_accuracy did not improve from 0.31429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 224s 2s/step - loss: 0.3714 - accuracy: 0.8734 - val_loss: 62.4412 - val_accuracy: 0.1714 - lr: 3.0000e-04
# Epoch 7/32
# 122/122 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.9079
# Epoch 7: val_accuracy did not improve from 0.31429
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 224s 2s/step - loss: 0.2428 - accuracy: 0.9079 - val_loss: 1.6939 - val_accuracy: 0.1857 - lr: 3.0000e-04
# Epoch 8/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1688 - accuracy: 0.9474
# Epoch 8: val_accuracy did not improve from 0.31429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 223s 2s/step - loss: 0.1688 - accuracy: 0.9474 - val_loss: 1.6670 - val_accuracy: 0.1714 - lr: 9.0000e-05
# Epoch 9/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9391
# Epoch 9: val_accuracy improved from 0.31429 to 0.32857, saving model to .\ct_effnet_best_model.hdf5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 218s 2s/step - loss: 0.1797 - accuracy: 0.9391 - val_loss: 1.5948 - val_accuracy: 0.3286 - lr: 9.0000e-05
# Epoch 10/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9589
# Epoch 10: val_accuracy did not improve from 0.32857
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 218s 2s/step - loss: 0.1336 - accuracy: 0.9589 - val_loss: 1.9442 - val_accuracy: 0.1571 - lr: 9.0000e-05
# Epoch 11/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9359
# Epoch 11: val_accuracy did not improve from 0.32857
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 218s 2s/step - loss: 0.1860 - accuracy: 0.9359 - val_loss: 2.2381 - val_accuracy: 0.1714 - lr: 9.0000e-05
# Epoch 12/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9539
# Epoch 12: val_accuracy did not improve from 0.32857
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 218s 2s/step - loss: 0.1300 - accuracy: 0.9539 - val_loss: 2.5404 - val_accuracy: 0.1857 - lr: 2.7000e-05
# Epoch 13/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9572
# Epoch 13: val_accuracy did not improve from 0.32857
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 216s 2s/step - loss: 0.1275 - accuracy: 0.9572 - val_loss: 2.3327 - val_accuracy: 0.2429 - lr: 2.7000e-05
# Epoch 14/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9638
# Epoch 14: val_accuracy improved from 0.32857 to 0.58571, saving model to .\ct_effnet_best_model.hdf5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 216s 2s/step - loss: 0.1194 - accuracy: 0.9638 - val_loss: 1.4511 - val_accuracy: 0.5857 - lr: 8.1000e-06
# Epoch 15/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9622
# Epoch 15: val_accuracy improved from 0.58571 to 0.84286, saving model to .\ct_effnet_best_model.hdf5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 216s 2s/step - loss: 0.1079 - accuracy: 0.9622 - val_loss: 0.5765 - val_accuracy: 0.8429 - lr: 8.1000e-06
# Epoch 16/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1251 - accuracy: 0.9539
# Epoch 16: val_accuracy improved from 0.84286 to 0.91429, saving model to .\ct_effnet_best_model.hdf5
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 220s 2s/step - loss: 0.1251 - accuracy: 0.9539 - val_loss: 0.3358 - val_accuracy: 0.9143 - lr: 8.1000e-06
# Epoch 17/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9605
# Epoch 17: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 213s 2s/step - loss: 0.1083 - accuracy: 0.9605 - val_loss: 0.5762 - val_accuracy: 0.8429 - lr: 8.1000e-06
# Epoch 18/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9688
# Epoch 18: val_accuracy did not improve from 0.91429
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 208s 2s/step - loss: 0.1088 - accuracy: 0.9688 - val_loss: 0.3819 - val_accuracy: 0.8857 - lr: 8.1000e-06
# Epoch 19/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1124 - accuracy: 0.9589
# Epoch 19: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 208s 2s/step - loss: 0.1124 - accuracy: 0.9589 - val_loss: 0.3591 - val_accuracy: 0.9000 - lr: 2.4300e-06
# Epoch 20/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1083 - accuracy: 0.9688
# Epoch 20: val_accuracy did not improve from 0.91429
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 204s 2s/step - loss: 0.1083 - accuracy: 0.9688 - val_loss: 0.3821 - val_accuracy: 0.9000 - lr: 2.4300e-06
# Epoch 21/32
# 122/122 [==============================] - ETA: 0s - loss: 0.0826 - accuracy: 0.9753
# Epoch 21: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.0826 - accuracy: 0.9753 - val_loss: 0.3698 - val_accuracy: 0.9000 - lr: 7.2900e-07
# Epoch 22/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9622
# Epoch 22: val_accuracy did not improve from 0.91429
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1185 - accuracy: 0.9622 - val_loss: 0.3574 - val_accuracy: 0.9000 - lr: 7.2900e-07
# Epoch 23/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9589
# Epoch 23: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1224 - accuracy: 0.9589 - val_loss: 0.3334 - val_accuracy: 0.9143 - lr: 2.1870e-07
# Epoch 24/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1016 - accuracy: 0.9720
# Epoch 24: val_accuracy did not improve from 0.91429
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 6.561000276406048e-08.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1016 - accuracy: 0.9720 - val_loss: 0.3764 - val_accuracy: 0.9000 - lr: 2.1870e-07
# Epoch 25/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1022 - accuracy: 0.9671
# Epoch 25: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1022 - accuracy: 0.9671 - val_loss: 0.3782 - val_accuracy: 0.9000 - lr: 6.5610e-08
# Epoch 26/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9671
# Epoch 26: val_accuracy did not improve from 0.91429
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.9683000829218145e-08.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1024 - accuracy: 0.9671 - val_loss: 0.3872 - val_accuracy: 0.9000 - lr: 6.5610e-08
# Epoch 27/32
# 122/122 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9770
# Epoch 27: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.0958 - accuracy: 0.9770 - val_loss: 0.3168 - val_accuracy: 0.9143 - lr: 1.9683e-08
# Epoch 28/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1165 - accuracy: 0.9622
# Epoch 28: val_accuracy did not improve from 0.91429
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.904900035602622e-09.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1165 - accuracy: 0.9622 - val_loss: 0.3825 - val_accuracy: 0.9000 - lr: 1.9683e-08
# Epoch 29/32
# 122/122 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9753
# Epoch 29: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.0916 - accuracy: 0.9753 - val_loss: 0.3659 - val_accuracy: 0.9143 - lr: 5.9049e-09
# Epoch 30/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1035 - accuracy: 0.9704
# Epoch 30: val_accuracy did not improve from 0.91429
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.7714700373261393e-09.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1035 - accuracy: 0.9704 - val_loss: 0.3822 - val_accuracy: 0.9000 - lr: 5.9049e-09
# Epoch 31/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9572
# Epoch 31: val_accuracy did not improve from 0.91429
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1289 - accuracy: 0.9572 - val_loss: 0.3850 - val_accuracy: 0.9000 - lr: 1.7715e-09
# Epoch 32/32
# 122/122 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9605
# Epoch 32: val_accuracy did not improve from 0.91429
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.314410245205181e-10.
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# 122/122 [==============================] - 205s 2s/step - loss: 0.1290 - accuracy: 0.9605 - val_loss: 0.3660 - val_accuracy: 0.9000 - lr: 1.7715e-09

# %% [markdown]
# # ✔️Model Evaluation

# %%
# Loading the Best Fit Model 
model_eff = load_model("./ct_effnet_best_model.hdf5")

# Checking the Accuracy of the Model 
accuracy_effnet = model_eff.evaluate_generator(generator= test_data)[1] 
loss_effnet = model_eff.evaluate_generator(generator= test_data)[0]
print(f"The accuracy of the model is = {accuracy_effnet*100} %")
print(f"The loss of the model is = {loss_effnet} %")
# Out:
# The accuracy of the model is = 90.47619104385376 %
# The loss of the model is = 0.34722715616226196 %

# %% [markdown]
# # **Model Comparison**
# <div style="background-color:#f2f2f2; padding: 20px;">
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# The accurate and timely identification of lung cancer from medical images is crucial for early diagnosis and effective treatment. To ensure the optimal performance of deep learning models, it is essential to conduct systematic comparisons.
#
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">Basics for comparing these models include evaluating their accuracy and loss values for training and validation. However, other metrics such as precision, recall or F1-score should be considered.

# %%
algos = ['VGG16', 'InceptionV3', 'EfficientNetB0']
accuracy = [accuracy_vgg, accuracy_incep, accuracy_effnet]
accuracy = np.floor([i * 100 for i in accuracy])


fig, ax = plt.subplots()
bars = ax.bar(algos, accuracy, color='skyblue')

# Add data values on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 3), ha='center', va='bottom')

# Add labels and title
plt.xlabel('Models')
plt.ylabel('Accuracy')
plt.title('Model Accuracy Comparison')


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


plt.show()

# %%
algos = ['VGG16', 'InceptionV3', 'EfficientNetB0']
loss = [loss_vgg, loss_incep, loss_effnet]

fig, ax = plt.subplots()
bars = ax.bar(algos, loss, color='skyblue')

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 3), ha='center', va='bottom')

plt.xlabel('Models')
plt.ylabel('Loss')
plt.title('Model Loss Comparison')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.yaxis.set_ticks_position('left')
ax.xaxis.set_ticks_position('bottom')


plt.show()

# %% [markdown]
# # Deployment Model
#
#
# <div style="background-color:#f2f2f2; padding: 20px;">
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">A well-performing model strikes a balance between high accuracy and low loss. It's beneficial to consider both metrics simultaneously, looking for a model that achieves good accuracy without sacrificing generalization (as reflected in the validation loss).

# %% [markdown]
# # 📉Visualizing  accuracy and loss curves
#
#
# <div style="background-color:#f2f2f2; padding: 20px;">
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">Interpreting a graph of accuracy for training and validation provides valuable insights into the performance of a machine learning model during training.
#
# <h3>Accuracy Curve:</h3>
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# Ideally, the training accuracy tends to increase as the model learns from the training data. This indicates that the model is effectively capturing patterns and features in the training set. Over time, the training accuracy may reach a plateau. The validation accuracy will follow the same trend, indicating that the model is generalizing well to unseen data, mirroring its performance on the training set.
#
# <h3>Loss Curve:</h3>
# <p style="font-size:20px; font-family:verdana; line-height: 1.7em">
# The training loss should generally exhibit a decreasing trend, indicating that the model is learning and optimizing its parameters to minimize the difference between predicted and actual values on the training data. Some fluctuations are normal, especially in the early epochs. The validation loss cruve should follow the same trend.

# %%
# !wget https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
from helper_functions import create_tensorboard_callback, plot_loss_curves, unzip_data, compare_historys, walk_through_dir, pred_and_plot

accuracy = EffNetB0.history['accuracy']
val_accuracy = EffNetB0.history['val_accuracy']

loss = EffNetB0.history['loss']
val_loss = EffNetB0.history['val_loss']

epochs = range(len(accuracy))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

ax1.plot(epochs, accuracy, 'b', label='Training accuracy')
ax1.plot(epochs, val_accuracy, 'r', label='Validation accuracy')
ax1.set_title('Training and validation accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend()

ax2.plot(epochs, loss, 'b', label='Training loss')
ax2.plot(epochs, val_loss, 'r', label='Validation loss')
ax2.set_title('Training and validation loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend()

fig.suptitle('Training and validation metrics', fontsize=16)
plt.show()
# Out:
# --2024-03-08 06:33:35--  https://raw.githubusercontent.com/mrdbourke/tensorflow-deep-learning/main/extras/helper_functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8003::154, 2606:50c0:8000::154, 2606:50c0:8001::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8003::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10246 (10K) [text/plain]
# Saving to: 'helper_functions.py'
#
#      0K ..........                                            100% 13.6M=0.001s
#
# 2024-03-08 06:33:35 (13.6 MB/s) - 'helper_functions.py' saved [10246/10246]

# %% [markdown]
# # 🔮Making predictions

# %%
def chestScanPrediction(path, _model, actual_label):
    classes_dir = ["Adenocarcinoma", "Large cell carcinoma", "Normal", "Squamous cell carcinoma"]
    num_images = len(paths)
    for i in range(num_images):
        # Loading Image
        img = image.load_img(paths[i], target_size=(350, 350))

        # Normalizing Image
        norm_img = image.img_to_array(img) / 255

        # Converting Image to Numpy Array
        input_arr_img = np.array([norm_img])

        # Getting Predictions
        pred = np.argmax(_model.predict(input_arr_img))

        # Printing Model Prediction
        print("Predicted Label:", classes_dir[pred])
        print("Actual Label:", classes_dir[actual_label[i]])
        
        # Displaying the image
        plt.imshow(img)
        plt.title("Actual Label: " + classes_dir[actual_label[i]] + "\nPredicted Label: " + classes_dir[pred])
        plt.show()

# %%
paths = [
    "Data/test/large.cell.carcinoma/000128.png",
    "Data/test/adenocarcinoma/000114.png",
    "Data/test/normal/21.png",
    "Data/test/squamous.cell.carcinoma/000119.png"
]

actual_labels = [1, 0, 2, 3]

chestScanPrediction(paths, EffNetmodel, actual_labels)
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted Label: Large cell carcinoma
# Actual Label: Large cell carcinoma
# 1/1 [==============================] - 0s 107ms/step
# Predicted Label: Adenocarcinoma
# Actual Label: Adenocarcinoma
# 1/1 [==============================] - 0s 100ms/step
# Predicted Label: Normal
# Actual Label: Normal
# 1/1 [==============================] - 0s 96ms/step
# Predicted Label: Squamous cell carcinoma
# Actual Label: Squamous cell carcinoma

# %%
EffNetmodel.save("EffNetModel.h5")
# EffNetB0.save("EffNetB0_history.h5")

vgg_model.save("VGGModel.h5")
# vgg.save("VGG_history.h5")

model_incep.save("IncepModel.h5")
# incep.save("Incep_history.h5")

# %%
# save the history of the models
import pickle
with open('EffNetB0_history', 'wb') as file_pi:
    pickle.dump(EffNetB0.history, file_pi)
    
with open('VGG_history', 'wb') as file_pi:
    pickle.dump(vgg.history, file_pi)
    
with open('Incep_history', 'wb') as file_pi:
    pickle.dump(incep.history, file_pi)
